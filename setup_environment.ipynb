# %%
# 1. Create the virtual environment
# !python -m venv .venv

# (Note: For MacOS/Linux, change `.venv\Scripts\pip` to `.venv/bin/pip`)
! .venv\Scripts\pip install -r requirements.txt

print("✅ All required packages installed successfully!")
# Out:
# Unable to copy 'c:\\Users\\minht\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\venv\\scripts\\nt\\venvlauncher.exe' to 'd:\\Academic_materials\\HK252\\ML\\src\\.venv\\Scripts\\python.exe'
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu126
# ...
#   Using cached transformers-5.7.0-py3-none-any.whl.metadata (33 kB)
# ...
#   Using cached huggingface_hub-1.13.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached regex-2026.4.4-cp314-cp314-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# ...
#   Using cached hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# ...
